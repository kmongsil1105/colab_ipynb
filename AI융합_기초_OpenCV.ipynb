# %% [markdown]
# <a href="https://colab.research.google.com/github/kmongsil1105/colab_ipynb/blob/main/AI%EC%9C%B5%ED%95%A9_%EA%B8%B0%EC%B4%88_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
cv2.__version__
# Out:
# '4.1.2'

# %%
import numpy
numpy.__version__
# Out:
# '1.19.5'

# %%
! pwd
# Out:
# /content

# %%
! cat /etc/issue  # Colab에 들어있는 Ubuntu image 버전 : 업데이트가 안되어 있음!!
# Out:
# Ubuntu 18.04.5 LTS \n \l

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

image = img.imread('/content/drive/MyDrive/IU.png')
# image = img.imread('./IU.png')
plt.imshow(image)
plt.show()

# %%
import cv2

img_file = '/content/drive/MyDrive/IU.png'     # 이미지 불러오기
img = cv2.imread(img_file)  # 이미지 변수 할당
type(img)                

# 불러온 image의 type을 확인한 결과 Numpy 배열임을 확인
# Out:
# numpy.ndarray

# %%
# OpenCV는 기본적으로 이미지를 3차원 배열, 즉 행 X 열 X 채널로 표현
# 행과 열은 이미지의 크기, 즉 높이와 폭만큼의 길이를 갖고 
# 채널은 컬러인 경우 파랑, 초록, 빨강 3개의 길이를 갖는다
img.ndim
# Out:
# 3

# %%
# 일반적인 이미지를 읽었을 때 3차원 배열은 `높이 X 폭 X 3` 형태
# `행 X 열 X 3`
img.shape
# Out:
# (345, 300, 3)

# %%
# img.size는 전체 요소의 개수로 각 차원의 길이를 곱한 값과 같다.
img.size
# Out:
# 310500

# %%
# 이미지 픽셀 데이터는 음수이거나 소수점을 갖는 경우가 없고, 
# 값의 크기도 최대 255이므로 부호 없는 8비트, 
# 즉 `uint8`을 데이터 타입으로 사용한다. ==> 1바이트의 부호없는 정수이므로 0~255까지 표현됨
img.dtype
# Out:
# dtype('uint8')

# %%
# 각 요소의 크기가 1바이트 인것을 나타낸다.
img.itemsize
# Out:
# 1

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [204, 204, 204],
#         [204, 204, 204],
#         [204, 204, 204]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [204, 204, 204],
#         [204, 204, 204],
#         [204, 204, 204]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [204, 204, 204],
#         [204, 204, 204],
#         [204, 204, 204]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [201, 191, 185],
#         ...,
#         [186, 169, 159],
#         [190, 179, 173],
#         [198, 197, 197]],
#
#        [[255, 255, 255],
#         [250, 249, 249],
#         [186, 173, 163],
#         ...,
#         [185, 167, 157],
#         [188, 178, 171],
#         [195, 194, 193]],
#
#        [[204, 204, 204],
#         [192, 190, 189],
#         [177, 160, 147],
# ...
