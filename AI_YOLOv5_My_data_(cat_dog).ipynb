# %% [markdown]
# <a href="https://colab.research.google.com/github/kmongsil1105/colab_ipynb/blob/main/AI_YOLOv5_My_data_(cat_dog).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # yolov5 폴더 생성
# %cd yolov5
# %pip install -r requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu102 (Tesla K80)

# %%
# train_data.zip 파일을 /content에 업로드 후에 작업
# !unzip -q ../train_data.zip -d ../

# /content/train_data폴더가 생기고 미리 만들어 둔 images, labels도 포함되어 있음
# 폴더생성 확인후에는 train_data.zip 파일 제거 가능!!

# %%
# 편집해서 저장해 놓은 custom_data.yaml 파일을 yolov5 아래에 업로드!!!
# %cat /content/yolov5/custom_data.yaml
# Out:
# train: ../train_data/images/train     # train images
# val: ../train_data/images/val      # val images
#
# # Classes
# nc: 2  # number of classes
#
# names: ['cat' , 'dog']  # class names

# %% [markdown]
# # Train

# %%
# %cd /content/yolov5

# ! python train.py --img 416 --batch 16 --epochs 50 --data /content/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name raccon_yolov5s_result
! python train.py --img 640 --batch 10 --epochs 50 --data ./custom_data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --cache --name cat_dog_yolov5s_result
# Out:
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/49     2.26G    0.1136   0.04913   0.02919        37       640: 100% 3/3 [00:01<00:00,  1.59it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  1.91it/s]
#                  all         10         20     0.0128      0.202     0.0074    0.00195
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/49     2.26G    0.1219   0.04644   0.03089        32       640: 100% 3/3 [00:01<00:00,  1.57it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:00<00:00,  2.00it/s]
#                  all         10         20     0.0212     0.0455      0.008    0.00234
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/49     2.26G   0.08387   0.04514   0.02313        33       640: 100% 3/3 [00:01<00:00,  1.61it/s]
# ...

# %%
# %cd /content/yolov5

! python detect.py --source ./cat_dog_img.jpg --weights ./runs/train/cat_dog_yolov5s_result/weights/best.pt --img 640 --conf 0.25
# Out:
# /content/yolov5
# detect: weights=['./runs/train/cat_dog_yolov5s_result/weights/best.pt'], source=./cat_dog_img.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-453-g8ad9e4e torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/yolov5/cat_dog_img.jpg: 384x640 Done. (0.025s)
# Speed: 0.4ms pre-process, 24.7ms inference, 0.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# %cd /content/yolov5

! python detect.py --source ./cat_dog.mp4 --weights ./runs/train/cat_dog_yolov5s_result/weights/last.pt --img 640 --conf 0.5
# Out:
# /content/yolov5
# detect: weights=['./runs/train/cat_dog_yolov5s_result/weights/last.pt'], source=./cat_dog.mp4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-453-g8ad9e4e torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients, 16.3 GFLOPs
# video 1/1 (1/6774) /content/yolov5/cat_dog.mp4: 384x640 Done. (0.025s)
# video 1/1 (2/6774) /content/yolov5/cat_dog.mp4: 384x640 Done. (0.024s)
# video 1/1 (3/6774) /content/yolov5/cat_dog.mp4: 384x640 Done. (0.024s)
# video 1/1 (4/6774) /content/yolov5/cat_dog.mp4: 384x640 Done. (0.024s)
# video 1/1 (5/6774) /content/yolov5/cat_dog.mp4: 384x640 Done. (0.024s)
# ...
