# %% [markdown]
# <a href="https://colab.research.google.com/github/kmongsil1105/colab_ipynb/blob/main/AI_PyTorch(%EB%AF%B8%EB%8B%88%EB%B0%B0%EC%B9%98%26%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A1%9C%EB%93%9C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더

# %%
x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %%
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    print(batch_idx)
    #print("             \n")
    print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch    0/20 Batch 1/3 Cost: 1.991340
# 1
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch    0/20 Batch 2/3 Cost: 0.632321
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    0/20 Batch 3/3 Cost: 2.764231
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    1/20 Batch 1/3 Cost: 1.425731
# 1
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch    1/20 Batch 2/3 Cost: 2.088257
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    1/20 Batch 3/3 Cost: 1.950765
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch    2/20 Batch 1/3 Cost: 0.024227
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# ...

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[152.1519]], grad_fn=<AddmmBackward>)
